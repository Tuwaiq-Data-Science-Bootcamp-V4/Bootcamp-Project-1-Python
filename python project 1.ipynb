# %% [markdown]
# ## Python project 1
# interactive quiz

# %%
# dic to store the info of the student at Tuwaiq Academy
bootcamp={
    "student1" : {
    "Name" : "Amal",
    "ID" : '1111111111',
    "bootcampName": 'Data-Science'
  },
  "student2" : {
    "Name" : "Sarah",
    "ID" : '1111111112',
    "bootcampName": 'Swift'
  },
  "student3" : {
    "Name" : "Ali",
    "ID" : '1111111113',
    "bootcampName": 'Java'
  },
  "student4" : {
    "Name" : "Fatin",
    "ID" : '1111111114',
    "bootcampName": 'Data-Science'
  },
}

lisName=[]    
lisID=[]
lisBootcamp=[]
num=0
for key, value in  bootcamp.items():
        lisName.append(value["Name"])
        lisID.append(value["ID"])
        lisBootcamp.append(value["bootcampName"])
        
# dic to store qustion and option for the quiz
quiz={
    "Data-Science" : {
           "qustion" : {
                        "Python supports the creation of anonymous functions at runtime, using a construct called "
                          : "A",
                        "What is the correct way to create a function in Python? ":"B",

                        "Which of these collections defines a LIST? ": "C"},

          "option" : [["A. lambda", "B. pi", "C. anonymous", "D. none of the mentioned"],
                      ["A. creat myFun():", "B. def myFun():", "C. function myFun():", "D. all of above"],
                      ["A. {'a','b'}", "B. ('a','b')", "C. ['a','b']", "D. {'a':'b','c':'d'}"]],
           "url"   :'https://edabit.com/challenges/python3'

   
  },
  "Java" : {
           "qustion" : {
                  "Which component is used to compile, debug and execute the java programs? ": "A",
                  "Which of the following is not an OOPS concept in Java? ": "B",
                  "Which one of the following is not a Java feature? ": "C"},

          "option" : [["A. JDK", "B. JIT", "C. JRE", "D. JVM"],
                ["A. Polymorphism", "B. Compilation", "C. Inheritance", "D. Encapsulation"],
                ["A. Object-oriented", "B. Portable", "C. Use of pointers", "D. Dynamic and Extensible"]],
          "url"  : 'https://edabit.com/challenges/java'

   
  },
     "Swift" : {
           "qustion" : {
                        "What are the collection types in Swift? ": "A",
                        "Which Of The Following Is Incorrect Data Type In SWIFT? ": "B",
                        "We Can Return Multiple Values In Swift From Function By Using ": "C"},


          "option" : [["A. Dictionary and array", "B. Array and library", "C. Dictionary and library", "D. Library, dictionary and array"],
                      ["A. UInt", "B. Char", "C. Double", "D. Optional"],
                      ["A. Both (B) and (C)", "B. Array", "C. Tuple", "D. None of the above"]],
           "url"   : 'https://edabit.com/challenges/swift'

   
  }
}

def checkAnswer(answer, guess):
    if answer== guess:
        print("CORRECT!")
        return 1
    else:
        print("WRONG!")
        return 0
    
def playAgain():

    response = input("Do you want to play again? (yes or no): ").lower()

    if response == "yes":
        return True
    else:
        return False   

def startQuiz():

    guesses = []
    correctGuesses = 0
    questionNum = 0

    for key,v in quiz.items():
        if key==x:
            break
    for z,y in v.items():
        if z=='qustion':
            break
    for e in y:
        print("-------------------------")
        print(e)
        for z1,y1 in v.items():
            if z1=='option':
                break
        for e1 in y1[questionNum]:
            print(e1)
        guess = input("Enter (A, B, C, or D): ").upper()
        guesses.append(guess)
        correctGuesses+=checkAnswer(y.get(e),guess)
        questionNum += 1

    score= lambda correctGuesses,questionNum : (correctGuesses/questionNum)*100
    print(f'Your score is {score(correctGuesses,questionNum)} %')
    for z2,y2 in v.items():
            if z2=='url':
                print('for more challenging quizzes we recommend you to visit the following website '+y2)
    

# check if users are register in Tuwaiq Academy         
checkUser = input("Welcome to our interactive quiz website. Are you a student at Tuwaiq Academy? write 'yes' or 'no' ").lower() 
if checkUser=='yes':
    idNumber= input("please enter your ID number ")
    if len(idNumber)!=10 or idNumber.isdigit()!=True:
            print('This is invalid ID')
    elif idNumber in lisID:
            num=lisID.index(idNumber)
            x=lisBootcamp[num]
            print(f'Welcome {lisName[num]} you are in {lisBootcamp[num]} bootcamp.')
            print("ALRIGHT! lets start a quick quiz")
            startQuiz()
            while playAgain():
                startQuiz()
    else:
        print("Sorry, it seems that you are not register in the Tuwaiq Academy bootcamp")
else:
    print('Sorry it is only for Tuwaiq Academy students')
# Out:
# Welcome to our interactive quiz website. Are you a student at Tuwaiq Academy? write 'yes' or 'no' yes
# please enter your ID number 1111111114
# Welcome Fatin you are in Data-Science bootcamp.
# ALRIGHT! lets start a quick quiz
# -------------------------
# Python supports the creation of anonymous functions at runtime, using a construct called
# A. lambda
# B. pi
# C. anonymous
# D. none of the mentioned
# Enter (A, B, C, or D): A
# CORRECT!
# -------------------------
# What is the correct way to create a function in Python?
# A. creat myFun():
# B. def myFun():
# C. function myFun():
# D. all of above
# Enter (A, B, C, or D): B
# CORRECT!
# -------------------------
# Which of these collections defines a LIST?
# A. {'a','b'}
# B. ('a','b')
# C. ['a','b']
# D. {'a':'b','c':'d'}
# Enter (A, B, C, or D): A
# WRONG!
# Your score is 66.66666666666666 %
# for more challenging quizzes we recommend you to visit the following website https://edabit.com/challenges/python3
# ...
